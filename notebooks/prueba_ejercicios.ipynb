# %%
import sys
sys.path.append('../src')

# %%
import ej1

# %%
ej1.ej_1()
# Out:
# Total de lineas:  19
# Total de palabras: 137
# Promedio palabras por linea: 7.21
# Lineas por encima del promedio:
#  - "    Special cases aren't special enough to break the rules." (9 palabras)
#  - "    In the face of ambiguity, refuse the temptation to guess." (10 palabras)
#  - "    There should be one-- and preferably only one --obvious way to do it." (13 palabras)
#  - "    Although that way may not be obvious at first unless you're Dutch." (12 palabras)
#  - "    Although never is often better than *right* now." (8 palabras)
#  - "    If the implementation is hard to explain, it's a bad idea." (11 palabras)
#  - "    If the implementation is easy to explain, it may be a good idea." (13 palabras)
#  - "    Namespaces are one honking great idea -- let's do more of those!" (12 palabras)

# %%
import ej2

# %%
ej2.ej_2()
# Out:
# Duración total: 46m 53s
# Cancion mas larga: Stairway to Heaven (8:02)
# Cancion mas corta: Imagine (3:07)

# %%
import ej3

# %%
ej3.ej_3()
# Out:
# ingrese las palabras consideradas spoilers separadas por comas:  marte
# ['marte']
#
# Texto censurado
#
# La película sigue a un grupo de astronautas que viajan a ***** en una misión de rescate. El capitán Torres lidera al equipo a través de tormentas solares y fallos en el sistema de navegación. Al llegar a ***** descubren que la base está abandonada y los suministros destruidos. Torres decide sacrificar la nave nodriza para salvar al equipo y logran volver a la Tierra en una cápsula de emergencia. El final revela que Torres sobrevivió gracias a un pasaje secreto.

# %%
import ej4

# %%
ej4.ej_4()
# Out:
# ingrese un email:  santiago@gmail.com
# email valido

# %%
import ej5

# %%
ej5.costo_envio()
# Out:
# ingrese el peso del paquete (en kg):  4.22
# Ingrese la zona de destino (local/regional/nacional):  regioNAl
# Costo de envio: $ 2500

# %%
import ej6

# %%
ej6.hashtags()
# Out:
# Hashtags trending (más de una aparición):
#  #Python: 3
#  #Programación: 3
#  #InteligenciaArtificial: 3
#  #Motivación: 2
#  #SerieAdicta: 2
#  #Tecnología: 2
# Total hashtags unicos:  13

# %%
import ej7

# %%
ej7.amigo_invisble()
# Out:
# Ingrese los participantes (separados por coma):  ana, marco, marcos
# Sorteo de amigo invisible:
# Ana → Marco
# Marco → Marcos
# Marcos → Ana

# %%
import ej8

# %%
ej8.cifrado()
# Out:
# ingrese un mensaje:  vamos ginasia
# ingrese un desplazamiento:  7
# mensaje cifrado:  chtvz npuhzph
# mensaje descifrado:  vamos ginasia

# %%
import ej9

# %%
ej9.alumnos()
# Out:
# Registros limpios de alumnos:
# Nombre               Nota       Estado
# --------------------------------------
# Ana García           9     Aprobado
# Carlos Ruiz          6     Aprobado
# Gabriela Ríos        5     Aprobado
# Laura Méndez         8     Aprobado
# María Fernández      10    Aprobado
# Pedro López          4     Desaprobado
# Sofía Torres         9     Aprobado
#
# Total de alumnos validos:  7

# %%
import ej10

# %%
ej10.master_chef()
# Out:
# Ronda 1 - Entrada:
#  Ganador: Camila (26 pts.)
#
# Tabla parcial:
# Cocinero          Puntaje  Rondas Ganadas  Mejor Ronda  Promedio
# -----------------------------------------------------------------
# Camila             26       1               26            26.0
# Valentina          24       0               24            24.0
# Lucía              24       0               24            24.0
# Mateo              22       0               22            22.0
# Santiago           19       0               19            19.0
# -----------------------------------------------------------------
#
# Ronda 2 - Plato principal:
#  Ganador: Valentina (26 pts.)
#
# Tabla parcial:
# Cocinero          Puntaje  Rondas Ganadas  Mejor Ronda  Promedio
# -----------------------------------------------------------------
# Valentina          50       1               26            25.0
# Mateo              46       0               24            23.0
# ...
